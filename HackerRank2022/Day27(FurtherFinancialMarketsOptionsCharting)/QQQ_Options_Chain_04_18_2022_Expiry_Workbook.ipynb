# %%
import pandas as pd
import numpy as np

# %%
# 04/18/2022 qqq puts/calls open interest
qqq_04_18_2022 = pd.read_csv(r'QQQ_Options_Chain_04_20_2022_Expiry.csv')

# %%
qqq_04_18_2022.head()
# Out:
#    CallVolume  CallOpenInt  Strike  PutVolume  PutOpenInt
# 0           0           17     314         63          87
# 1          10            7     315        592        1315
# 2           0           10     316        104         783
# 3           1            1     317       2887         306
# 4           5           15     318        477         503

# %%
# 04/18/2022 qqq puts/calls open interest
qqq_04_18_2022 = qqq_04_18_2022[['CallVolume','CallOpenInt','Strike','PutVolume','PutOpenInt']]

# %%
# 04/18/2022 qqq puts/calls open interest
qqq_04_18_2022
# Out:
#     CallVolume  CallOpenInt  Strike  PutVolume  PutOpenInt
# 0            0           17     314         63          87
# 1           10            7     315        592        1315
# 2            0           10     316        104         783
# 3            1            1     317       2887         306
# 4            5           15     318        477         503
# 5            2            1     319        413         522
# 6           10           22     320       1111        1634
# 7            1            1     321       1657         112
# 8           24           11     322        573         487
# 9            6           27     323       1025         433
# 10           7            5     324        896        1022
# 11        1015           51     325       3632        4647
# 12           2           10     326       1309         864
# 13           4           38     327       2530         766
# 14          12           79     328       5628         969
# ...

# %%
qqq_04_18_2022_copy = qqq_04_18_2022.copy()

# %%
# runningTotal = 0
# for i in qqq_04_18_2022_copy['CallOpenInt']:
# #     print(i)
#     runningTotal += i
# #     print(runningTotal)
#     qqq_04_18_2022_copy['CallOpenIntRunningTotal']

# %%
# qqq_04_18_2022_copy.iloc[0, qqq_04_18_2022_copy.columns.get_loc('CallOpenIntRunningTotal')] = 11

# %%
# for count, value in qqq_04_18_2022_copy['CallOpenIntRunningTotal']:
#     print(count, value)

# row = next(qqq_04_18_2022_copy.iterrows())[1][5]
# row

# %%
qqq_04_18_2022_copy
# Out:
#     CallVolume  CallOpenInt  Strike  PutVolume  PutOpenInt
# 0            0           17     314         63          87
# 1           10            7     315        592        1315
# 2            0           10     316        104         783
# 3            1            1     317       2887         306
# 4            5           15     318        477         503
# 5            2            1     319        413         522
# 6           10           22     320       1111        1634
# 7            1            1     321       1657         112
# 8           24           11     322        573         487
# 9            6           27     323       1025         433
# 10           7            5     324        896        1022
# 11        1015           51     325       3632        4647
# 12           2           10     326       1309         864
# 13           4           38     327       2530         766
# 14          12           79     328       5628         969
# ...

# %%
# 04/18/2022 qqq puts/calls open interest
calls = qqq_04_18_2022['CallOpenInt']
puts = qqq_04_18_2022['PutOpenInt']
strikes = qqq_04_18_2022['Strike']

strikes = [x for x in qqq_04_18_2022['Strike']]
len(strikes)
# Out:
# 60

# %%
# 04/18/2022 qqq puts/calls open interest
callsX = []
for x in qqq_04_18_2022['Strike']:
    x = x +.4
    callsX.append(x)
print(callsX)
# Out:
# [314.4, 315.4, 316.4, 317.4, 318.4, 319.4, 320.4, 321.4, 322.4, 323.4, 324.4, 325.4, 326.4, 327.4, 328.4, 329.4, 330.4, 331.4, 332.4, 333.4, 334.4, 335.4, 336.4, 337.4, 338.4, 339.4, 340.4, 341.4, 342.4, 343.4, 344.4, 345.4, 346.4, 347.4, 348.4, 349.4, 350.4, 351.4, 352.4, 353.4, 354.4, 355.4, 356.4, 357.4, 358.4, 359.4, 360.4, 361.4, 362.4, 363.4, 364.4, 365.4, 366.4, 367.4, 368.4, 369.4, 370.4, 371.4, 372.4, 373.4]

# %%
# 04/18/2022 qqq puts/calls open interest
import matplotlib.pyplot as plt
# Data to be used for bars
data = [puts,
calls]
# Strikes for X axis
X = strikes
# Create a new figure
fig = plt.figure()

ax = fig.add_axes([0,0,20,10])
plt.xticks(fontsize=60)
plt.yticks(fontsize=100)
plt.xticks(strikes)
parameters = {'axes.titlesize': 100}
plt.rcParams.update(parameters)
plt.title('04/18/2022 QQQ Puts/Calls Open Interest')
line1 = ax.bar(X, data[0], color = 'r', width = 0.25, label='Puts')
line2 = ax.bar(callsX, data[1], color = 'g', width = 0.25, label='Calls')
# ax.bar(X, data[0], color = 'b', width = 0.25)
# ax.bar(callsX, data[1], color = 'g', width = 0.25)
# ax.legend(handles = [line1, line2], bbox_to_anchor=(0.35, 1.0), borderpad=50, prop={"size":50})
ax.legend(handles = [line1, line2], borderpad=2, prop={"size":100})

# %%
qqq_04_20_2022 = pd.read_csv(r'QQQ_Options_Chain_04_22_2022_Expiry.csv')

# %%
qqq_04_20_2022
# Out:
#     CallVolume  CallOpenInt  Strike  PutVolume  PutOpenInt
# 0           78           13   317.0        297        2046
# 1           12           67   318.0       3623        4176
# 2            6          120   319.0        141        1113
# 3           79          122   320.0       1706       12561
# 4            0           88   321.0        699        1798
# 5           11          157   322.0        235        2700
# 6            0           88   323.0       2439        7886
# 7           23          139   324.0        485        1641
# 8          108          293   325.0       7807       19349
# 9            0          210   326.0        749        1640
# 10          17           94   327.0        863        2547
# 11          11          123   328.0       4747        9270
# 12           5          120   329.0       2346        5406
# 13         267          751   330.0      13452       17309
# 14         179           97   331.0       1275        3108
# ...

# %%
qqq_04_20_2022 = qqq_04_20_2022[['CallVolume','CallOpenInt','Strike','PutVolume','PutOpenInt']]

# %%
import math

# %%
for i in

# %%
import math
# Pushing calls x ticker .4 forward for separation on graph
callsX_qqq_04_20_2022 = []
for x in qqq_04_20_2022['Strike']:
    x = x +.4
    callsX_qqq_04_20_2022.append(x)
print(callsX_qqq_04_20_2022)
# Out:
# [317.4, 318.4, 319.4, 320.4, 321.4, 322.4, 323.4, 324.4, 325.4, 326.4, 327.4, 328.4, 329.4, 330.4, 331.4, 332.4, 332.9, 333.4, 334.4, 335.4, 336.4, 337.4, 337.9, 338.4, 339.4, 340.4, 341.4, 342.4, 342.9, 343.4, 344.4, 345.4, 346.4, 347.4, 347.9, 348.4, 349.4, 350.4, 351.4, 352.4, 352.9, 353.4, 354.4, 355.4, 356.4, 357.4, 357.9, 358.4, 359.4, 360.4, 361.4, 362.4, 362.9, 363.4, 364.4, 365.4, 366.4, 367.4, 368.4, 369.4]

# %%
calls_qqq_04_20_2022 = qqq_04_20_2022['CallOpenInt']
puts_qqq_04_20_2022 = qqq_04_20_2022['PutOpenInt']
strikes_qqq_04_20_2022 = qqq_04_20_2022['Strike']

# %%
strikes_qqq_04_20_2022.dtype
# Out:
# dtype('float64')

# %%
qqq_04_20_2022['CallStrikes'] = callsX_qqq_04_20_2022

# %%
qqq_04_20_2022['CallStrikes'].dtype
# Out:
# dtype('float64')

# %%
# qqq_04_20_2022 qqq puts/calls open interest
import matplotlib.pyplot as plt
data = [puts_qqq_04_20_2022,
calls_qqq_04_20_2022]
X = strikes_qqq_04_20_2022
fig = plt.figure()
ax = fig.add_axes([0,0,20,10])
plt.xticks(fontsize=40)
plt.yticks(fontsize=100)
plt.xticks(strikes_qqq_04_20_2022)
parameters = {'axes.titlesize': 100}
plt.rcParams.update(parameters)
plt.title('04/20/2022 QQQ Puts/Calls Open Interest')
line1 = ax.bar(X, data[0], color = 'r', width = 0.15, label='Puts')
line2 = ax.bar(callsX_qqq_04_20_2022, data[1], color = 'g', width = 0.15, label='Calls')
# ax.bar(X, data[0], color = 'b', width = 0.25)
# ax.bar(callsX, data[1], color = 'g', width = 0.25)
# ax.legend(handles = [line1, line2], bbox_to_anchor=(0.35, 1.0), borderpad=50, prop={"size":50})
ax.legend(handles = [line1, line2], borderpad=2, prop={"size":100})

# %%
qqq_04_22_2022 = pd.read_csv(r'QQQ_Options_Chain_04_22_2022_Expiry.csv')

# %%
qqq_04_22_2022
# Out:
#     CallVolume  CallOpenInt  Strike  PutVolume  PutOpenInt
# 0            0           87   310.0        776        3404
# 1            0            0   311.0       5210         117
# 2           45           28   312.0         25         288
# 3            0            0   313.0        482          14
# 4            0          270   314.0        154         470
# 5            0          335   315.0        745        2311
# 6           10           32   316.0       3273        4784
# 7            0            0   317.0       2528          24
# 8            2           63   318.0        481        1568
# 9           21          120   319.0        151         390
# 10          25          103   320.0       6548       14691
# 11           0           87   321.0        272        1508
# 12          22          139   322.0       2570         427
# 13           0           88   323.0        384        7510
# 14          19          124   324.0        673        1037
# ...

# %%
qqq_04_22_2022 = qqq_04_22_2022[['CallVolume','CallOpenInt','Strike','PutVolume','PutOpenInt']]

# %%
import math
# Pushing calls x ticker .4 forward for separation on graph
callsX_qqq_04_22_2022 = []
for x in qqq_04_22_2022['Strike']:
    x = x +.4
    callsX_qqq_04_22_2022.append(x)
print(callsX_qqq_04_22_2022)
# Out:
# [310.4, 311.4, 312.4, 313.4, 314.4, 315.4, 316.4, 317.4, 318.4, 319.4, 320.4, 321.4, 322.4, 323.4, 324.4, 325.4, 326.4, 327.4, 328.4, 329.4, 330.4, 331.4, 332.4, 332.9, 333.4, 334.4, 335.4, 336.4, 337.4, 337.9, 338.4, 339.4, 340.4, 341.4, 342.4, 342.9, 343.4, 344.4, 345.4, 346.4, 347.4, 347.9, 348.4, 349.4, 350.4, 351.4, 352.4, 352.9, 353.4, 354.4, 355.4, 356.4, 357.4, 357.9, 358.4, 359.4, 360.4, 361.4, 362.4, 362.9]

# %%
calls_qqq_04_22_2022 = qqq_04_22_2022['CallOpenInt']
puts_qqq_04_22_2022 = qqq_04_22_2022['PutOpenInt']
strikes_qqq_04_22_2022 = qqq_04_22_2022['Strike']

# %%
# qqq_04_20_2022 qqq puts/calls open interest
import matplotlib.pyplot as plt
data = [puts_qqq_04_22_2022,
calls_qqq_04_22_2022]
X = strikes_qqq_04_22_2022
fig = plt.figure()
ax = fig.add_axes([0,0,20,10])
plt.xticks(fontsize=60)
plt.yticks(fontsize=100)
plt.xticks(strikes_qqq_04_22_2022)
parameters = {'axes.titlesize': 100}
plt.rcParams.update(parameters)
plt.title('04/22/2022 QQQ Puts/Calls Open Interest')
line1 = ax.bar(X, data[0], color = 'r', width = 0.25, label='Puts')
line2 = ax.bar(callsX_qqq_04_22_2022, data[1], color = 'g', width = 0.25, label='Calls')
# ax.bar(X, data[0], color = 'b', width = 0.25)
# ax.bar(callsX, data[1], color = 'g', width = 0.25)
# ax.legend(handles = [line1, line2], bbox_to_anchor=(0.35, 1.0), borderpad=50, prop={"size":50})
ax.legend(handles = [line1, line2], borderpad=2, prop={"size":100})

# %%
spx_04_18_2022 = pd.read_csv(r'SPX_Options_Chain_04_18_2022_Expiry.csv')

# %%
spx_04_18_2022
# Out:
#     CallVolume  CallOpenInt  Strike  PutVolume  PutOpenInt
# 0            0           77    4350          0        2282
# 1            0           18    4355          0         337
# 2            0           35    4360          0         380
# 3            0            7    4365          0         486
# 4            0           43    4370          0         531
# 5            0           48    4375          0         284
# 6            0           55    4380          0         588
# 7            0           88    4385          0         281
# 8            0           57    4390          0         636
# 9            0          151    4395          0         450
# 10           0          417    4400          0        2866
# 11           0          102    4405          0         215
# 12           0          234    4410          0         575
# 13           0           98    4415          0         222
# 14           0          134    4420          0         464
# ...

# %%
spx_04_18_2022 = spx_04_18_2022[['CallVolume','CallOpenInt','Strike','PutVolume','PutOpenInt']]

# %%
import math
# Pushing calls x ticker .4 forward for separation on graph
callsX_spx_04_18_2022 = []
for x in spx_04_18_2022['Strike']:
    x = x +.4
    callsX_spx_04_18_2022.append(x)
print(callsX_spx_04_18_2022)
# Out:
# [4350.4, 4355.4, 4360.4, 4365.4, 4370.4, 4375.4, 4380.4, 4385.4, 4390.4, 4395.4, 4400.4, 4405.4, 4410.4, 4415.4, 4420.4, 4425.4, 4430.4, 4435.4, 4440.4, 4445.4, 4450.4, 4455.4, 4460.4, 4465.4, 4470.4, 4475.4, 4480.4]

# %%
strikes_spx_04_18_2022 = spx_04_18_2022['Strike']
calls_spx_04_18_2022 = spx_04_18_2022['CallOpenInt']
puts_spx_04_18_2022 = spx_04_18_2022['PutOpenInt']

# %%
# SPX_04_18_2022 qqq puts/calls open interest
import matplotlib.pyplot as plt
data = [puts_spx_04_18_2022,
calls_spx_04_18_2022]
X = strikes_spx_04_18_2022
fig = plt.figure()
ax = fig.add_axes([0,0,20,10])
plt.xticks(fontsize=60)
plt.yticks(fontsize=100)
plt.xticks(strikes_spx_04_18_2022)
parameters = {'axes.titlesize': 100}
plt.rcParams.update(parameters)
plt.title('04/18/2022 SPX Puts/Calls Open Interest')
line1 = ax.bar(X, data[0], color = 'r', width = 0.25, label='Puts')
line2 = ax.bar(callsX_spx_04_18_2022, data[1], color = 'g', width = 0.25, label='Calls')
# ax.bar(X, data[0], color = 'b', width = 0.25)
# ax.bar(callsX, data[1], color = 'g', width = 0.25)
# ax.legend(handles = [line1, line2], bbox_to_anchor=(0.35, 1.0), borderpad=50, prop={"size":50})
ax.legend(handles = [line1, line2], borderpad=2, prop={"size":100})

# %%
spx_04_20_2022 = pd.read_csv(r'SPX_Options_Chain_04_20_2022_Expiry.csv')

# %%
spx_04_20_2022
# Out:
#     CallVolume  CallOpenInt  Strike  PutVolume  PutOpenInt
# 0            0          115    4350          0        1855
# 1            0            7    4355          0         159
# 2            0           11    4360          0         241
# 3            0           13    4365          0         156
# 4            0           44    4370          0         196
# 5            0           31    4375          0         317
# 6            0           17    4380          0         322
# 7            0           21    4385          0         477
# 8            0            9    4390          0         560
# 9            0           32    4395          0         192
# 10           0          384    4400          0        1910
# 11           0          113    4405          0         196
# 12           0          123    4410          0         614
# 13           0           55    4415          0         214
# 14           0           70    4420          0         444
# ...

# %%
spx_04_20_2022 = spx_04_20_2022[['CallVolume','CallOpenInt','Strike','PutVolume','PutOpenInt']]

# %%
import math
# Pushing calls x ticker .4 forward for separation on graph
callsX_spx_04_20_2022 = []
for x in spx_04_20_2022['Strike']:
    x = x +.4
    callsX_spx_04_20_2022.append(x)
print(callsX_spx_04_20_2022)
# Out:
# [4350.4, 4355.4, 4360.4, 4365.4, 4370.4, 4375.4, 4380.4, 4385.4, 4390.4, 4395.4, 4400.4, 4405.4, 4410.4, 4415.4, 4420.4, 4425.4, 4430.4, 4435.4, 4440.4, 4445.4, 4450.4, 4455.4, 4460.4, 4465.4, 4470.4, 4475.4, 4480.4, 4485.4, 4490.4, 4495.4, 4500.4, 4505.4]

# %%
strikes_spx_04_20_2022 = spx_04_20_2022['Strike']
calls_spx_04_20_2022 = spx_04_20_2022['CallOpenInt']
puts_spx_04_20_2022 = spx_04_20_2022['PutOpenInt']

# %%
# SPX_04_20_2022 qqq puts/calls open interest
import matplotlib.pyplot as plt
data = [puts_spx_04_20_2022,
calls_spx_04_20_2022]
X = strikes_spx_04_20_2022
fig = plt.figure()
ax = fig.add_axes([0,0,20,10])
plt.xticks(fontsize=60)
plt.yticks(fontsize=100)
plt.xticks(strikes_spx_04_20_2022)
parameters = {'axes.titlesize': 100}
plt.rcParams.update(parameters)
plt.title('04/20/2022 SPX Puts/Calls Open Interest')
line1 = ax.bar(X, data[0], color = 'r', width = 0.25, label='Puts')
line2 = ax.bar(callsX_spx_04_20_2022, data[1], color = 'g', width = 0.25, label='Calls')
# ax.bar(X, data[0], color = 'b', width = 0.25)
# ax.bar(callsX, data[1], color = 'g', width = 0.25)
# ax.legend(handles = [line1, line2], bbox_to_anchor=(0.35, 1.0), borderpad=50, prop={"size":50})
ax.legend(handles = [line1, line2], borderpad=2, prop={"size":100})

# %%
spx_04_22_2022 = pd.read_csv(r'SPX_Options_Chain_04_22_2022_Expiry.csv')

# %%
spx_04_22_2022
# Out:
#     CallVolume  CallOpenInt  Strike  PutVolume  PutOpenInt
# 0            0          369    4350          0        2416
# 1            0           72    4355          0        1233
# 2            0           59    4360          0         265
# 3            0           44    4365          0         402
# 4            0           60    4370          0         310
# 5            0          218    4375          0        1511
# 6            0          100    4380          0        1197
# 7            0           34    4385          0         344
# 8            0           61    4390          0         466
# 9            0           80    4395          0         361
# 10           0         1090    4400          0        4299
# 11           0           80    4405          0         216
# 12           0          123    4410          0         427
# 13           0           57    4415          0         159
# 14           0          100    4420          0         309
# ...

# %%
spx_04_22_2022 = spx_04_22_2022[['CallVolume','CallOpenInt','Strike','PutVolume','PutOpenInt']]

# %%
import math
# Pushing calls x ticker .4 forward for separation on graph
callsX_spx_04_22_2022 = []
for x in spx_04_22_2022['Strike']:
    x = x +.4
    callsX_spx_04_22_2022.append(x)
print(callsX_spx_04_22_2022)
# Out:
# [4350.4, 4355.4, 4360.4, 4365.4, 4370.4, 4375.4, 4380.4, 4385.4, 4390.4, 4395.4, 4400.4, 4405.4, 4410.4, 4415.4, 4420.4, 4425.4, 4430.4, 4435.4, 4440.4, 4445.4, 4450.4, 4455.4, 4460.4, 4465.4, 4470.4, 4475.4, 4480.4, 4485.4, 4490.4, 4495.4, 4500.4, 4505.4]

# %%
strikes_spx_04_22_2022 = spx_04_22_2022['Strike']
calls_spx_04_22_2022 = spx_04_22_2022['CallOpenInt']
puts_spx_04_22_2022 = spx_04_22_2022['PutOpenInt']

# %%
# SPX_04_22_2022 qqq puts/calls open interest
import matplotlib.pyplot as plt
data = [puts_spx_04_22_2022,
calls_spx_04_22_2022]
X = strikes_spx_04_22_2022
fig = plt.figure()
ax = fig.add_axes([0,0,20,10])
plt.xticks(fontsize=60)
plt.yticks(fontsize=100)
plt.xticks(strikes_spx_04_22_2022)
parameters = {'axes.titlesize': 100}
plt.rcParams.update(parameters)
plt.title('04/22/2022 SPX Puts/Calls Open Interest')
line1 = ax.bar(X, data[0], color = 'r', width = 0.25, label='Puts')
line2 = ax.bar(callsX_spx_04_22_2022, data[1], color = 'g', width = 0.25, label='Calls')
# ax.bar(X, data[0], color = 'b', width = 0.25)
# ax.bar(callsX, data[1], color = 'g', width = 0.25)
# ax.legend(handles = [line1, line2], bbox_to_anchor=(0.35, 1.0), borderpad=50, prop={"size":50})
ax.legend(handles = [line1, line2], borderpad=2, prop={"size":100})
