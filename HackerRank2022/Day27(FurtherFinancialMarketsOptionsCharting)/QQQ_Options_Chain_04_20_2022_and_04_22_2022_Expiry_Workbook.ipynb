# %%
import pandas as pd
import numpy as np

# %%
# 04/20/2022 and 04/22/2022 qqq puts/calls open interest
qqq_4_20_2022_and_4_22_2022 = pd.read_csv(r'qqq_4_20_2022_and_4_22_2022.csv')

# %%
qqq_4_20_2022_and_4_22_2022
# Out:
#     Stock quote and option quote for QQQ on 4/19/22 23:34:42 Unnamed: 1  \
# 0                                           UNDERLYING              NaN
# 1                                                 LAST               LX
# 2                                               346.26                Q
# 3                                UNDERLYING EXTRA INFO              NaN
# 4                                            Last Size            Yield
# ..                                                 ...              ...
# 154                              17 MAR 23  (331)  100              NaN
# 155                 31 MAR 23  (345)  100 (Quarterlys)              NaN
# 156                              16 JUN 23  (422)  100              NaN
# 157                              15 DEC 23  (604)  100              NaN
# 158                              19 JAN 24  (639)  100              NaN
#
#     Unnamed: 2 Unnamed: 3 Unnamed: 4   Unnamed: 5 Unnamed: 6  Unnamed: 7  \
# ...

# %%
drop_list = [x for x in range(6)]
print(drop_list)
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
df = qqq_4_20_2022_and_4_22_2022.drop(axis=0, index =drop_list)
# df = qqq_4_20_2022_and_4_22_2022

# %%
df.head(20)
# Out:
#    Stock quote and option quote for QQQ on 4/19/22 23:34:42 Unnamed: 1  \
# 6                       20 APR 22  (0)  100 (Weeklys)              NaN
# 7                                                 NaN              NaN
# 8                                                 NaN              NaN
# 9                                                 NaN              NaN
# 10                                                NaN              NaN
# 11                                                NaN              NaN
# 12                                                NaN              NaN
# 13                                                NaN              NaN
# 14                                                NaN              NaN
# 15                                                NaN              NaN
# 16                                                NaN              NaN
# 17                                                NaN              NaN
# ...

# %%
import re
matches = ("7/17/7777 77:77", 'jwdajwf','3/17/7777 77:77')
r = re.compile('.*/.*/.*:.*')
if r.match('x/x/xxxx xx:xx') is not None:
#    print(matches)
    print(f'{r.match}')
# Out:
# <built-in method match of re.Pattern object at 0x00000242C7B9DC60>

# %%
pattern = re.compile("o")
print(pattern.match("dog"))      # No match as "o" is not at the start of "dog".
print(pattern.match("dog", 1))
if pattern.match("dog",1) is not None:
    print('hello')
# Out:
# None
# <re.Match object; span=(1, 2), match='o'>
# hello

# %%
pattern = re.compile("dog")
if pattern.match("dog") is not None:
    print('hello')
# Out:
# hello

# %%
import re

# %%
pattern = re.compile("o")

# %%
#identify start of options chain per expiry
for i in df['Stock quote and option quote for QQQ on 4/19/22 23:34:42']:
    if i is not np.nan:
        print(i)
# Out:
# 20 APR 22  (0)  100 (Weeklys)
# 22 APR 22  (2)  100 (Weeklys)
# 25 APR 22  (5)  100 (Weeklys)
# 27 APR 22  (7)  100 (Weeklys)
# 29 APR 22  (9)  100 (Weeklys)
# 2 MAY 22  (12)  100 (Weeklys)
# 4 MAY 22  (14)  100 (Weeklys)
# 6 MAY 22  (16)  100 (Weeklys)
# 9 MAY 22  (19)  100 (Weeklys)
# 11 MAY 22  (21)  100 (Weeklys)
# 13 MAY 22  (23)  100 (Weeklys)
# 16 MAY 22  (26)  100 (Weeklys)
# 18 MAY 22  (28)  100 (Weeklys)
# 20 MAY 22  (30)  100
# 23 MAY 22  (33)  100 (Weeklys)
# 25 MAY 22  (35)  100
# 27 MAY 22  (37)  100 (Weeklys)
# 17 JUN 22  (58)  100
# 30 JUN 22  (71)  100 (Quarterlys)
# 15 JUL 22  (86)  100
# 19 AUG 22  (121)  100
# 16 SEP 22  (149)  100
# 30 SEP 22  (163)  100 (Quarterlys)
# 16 DEC 22  (240)  100
# 30 DEC 22  (254)  100 (Quarterlys)
# 20 JAN 23  (275)  100
# 17 MAR 23  (331)  100
# 31 MAR 23  (345)  100 (Quarterlys)
# 16 JUN 23  (422)  100
# 15 DEC 23  (604)  100
# 19 JAN 24  (639)  100
